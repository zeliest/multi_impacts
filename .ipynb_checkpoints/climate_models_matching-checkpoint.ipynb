# %% [markdown]
# to do:
#
# function

# %%
from climada.util.api_client import Client
from climada.util.constants import RIVER_FLOOD_REGIONS_CSV
from climada_petals.entity.impact_funcs.river_flood import ImpfRiverFlood,flood_imp_func_set
import pandas as pd
from climada.engine import Impact
from climada.hazard import Hazard
import numpy as np
from climada.util import yearsets
import os
import matplotlib.pyplot as plt
import pandas as pd
import scipy as sp
from climada.util.multi_hazard import *
import datetime



countries = ['USA','TWN', 'HTI', 'MDG','COL', 'AUS', 'VNM']
def open_impacts(country, csv, impact_mat):
    try:
        impact = Impact.from_csv(csv)
        impact.imp_mat = impact.read_sparse_csr(impact_mat)
        return impact
    except:
        print("".join([" No data for ", str(country)]))
        return(None)

impact_csvs = {}
impact_mats = {}
impact_csvs_crops = {}
impact_mats_crops = {}
data_dir = '/Users/szelie/OneDrive - ETH Zurich/20211208_Multi-Impact_ZelieCarmen'
for country in countries:
    impact_csvs[country] = {}
    impact_mats[country] = {}
    impact_csvs_crops[country] = {}
    impact_mats_crops[country] = {}
    impact_csvs[country]['RF'] = os.path.join(data_dir, "".join(['RF_impact_mat/river_flood_impact_150arcsec_rcp60_2030_2050_',country,'.csv']))
    impact_mats[country]['RF'] = os.path.join(data_dir, "".join(['RF_impact_mat/river_flood_impact_150arcsec_rcp60_2030_2050_',country,'.npz']))


    #crops
    for crop in ['mai','ric','soy','whe']:
        impact_csvs_crops[country][crop] = os.path.join(data_dir, "".join(['CP_impact/ISIMIP2b/Impact_save_mat/imp_',country,'_',crop,'_rcp60_tonnes.csv']))
        impact_mats_crops[country][crop] = os.path.join(data_dir, "".join(['CP_impact/ISIMIP2b/Impact_save_mat/imp_mat_',country,'_',crop,'_rcp60_tonnes.npz']))

    #landslide

# %%
years = np.array(range(1,401))
hazard='RF'

impacts = {country:{hazard: open_impacts(country, impact_csvs[country][hazard], 
                                                  impact_mats[country][hazard]) for hazard in impact_csvs[country]} for country in impact_csvs}
impacts_yearsets = {country:{hazard: make_yearset(impacts[country][hazard], years) for hazard in impacts[country] if impacts[country][hazard]!=None} for country in impacts}

impacts_crops = {}
impact_crops_combined = {}
for country in impact_csvs_crops:
    impacts_crops[country] = {}
    for crop in impact_csvs_crops[country]:
        impact = Impact.from_csv(impact_csvs_crops[country][crop])
        impact.imp_mat = impact.read_sparse_csr(impact_mats_crops[country][crop])
        impacts_crops[country][crop] = impact
        impacts_list = list(impacts_crops[country].values())
        impact_crops_combined[country] = combine_yearly_impacts(impacts_list)
        impact_crops_combined[country] = impact_crops_combined[country].set_imp_mat(sp.sparse.csr_matrix(impact_crops_combined[country].imp_mat))

        impact_crops_combined[country] = impact_crops_combined[country].select(dates=(datetime.date.toordinal(datetime.date(2030, 1, 1)),datetime.date.toordinal(datetime.date(2050, 1, 1))))
        impact_crops_combined[country].frequency = np.ones(len(impact_crops_combined[country].event_id))/len(impact_crops_combined[country].event_id)
for country in impact_crops_combined:
    impacts_yearsets[country]['CP'] = impact_crops_combined[country]
    impacts[country]['CP'] = make_yearset(impact_crops_combined[country], years)
# Out:
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:812: DtypeWarning: Columns (0,1,2,3,7,14) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:812: DtypeWarning: Columns (0,1,2,3,7,14) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)

# %%
climate_models = ['miroc5','ipsl-cm5a-lr','gfdl-esm2m','hadgem2-es']
years = np.arange(2030,2050)
impacts_yearsets_ordered = {}
impacts_yearsets_ordered = {country: make_consistent_drivers_yearsets(impacts[country], 4, list_climate_models=climate_models, list_years=years) for country in countries}

# %%
def make_correlation_matrix(impact_dict, temporal=True,spatial=False):
    if temporal is True and spatial is False:
        df = pd.DataFrame.from_dict({hazard: impact_dict[hazard].at_event for hazard in impact_dict})
    return df.corr()

# %%
country
# Out:
# 'VNM'

# %%
corr_matrices = {country: make_correlation_matrix(impacts_yearsets_ordered[country]) for country in impacts_yearsets_ordered}

# %%
corr_matrices
# Out:
# <AxesSubplot:title={'center':'Exceedance frequency curve'}, xlabel='Return period (year)', ylabel='Impact ()'>

# %%
climate_models = ['miroc5','ipsl-cm5a-lr','gfdl-esm2m','hadgem2-es']
years = np.arange(2030,2050)

# %%
impacts_yearsets_crops_ordered = {country: {'CP': [order_climate_driver(impacts_yearsets_crops[country]['CP'][0], climate_models, years)]} for country in impacts_yearsets_crops}
impacts_yearsets_ordered = {country: {hazard: [order_climate_driver(impacts_yearsets[country][hazard][0], climate_models, years)] for hazard in impacts_yearsets[country]} for country in impacts_yearsets}
#impacts_yearsets_crops_ordered = {country: {'CP':[regrid_impact(impacts_yearsets_crops_ordered[country]['CP'][0],impacts_yearsets_ordered[country]['RF'][0])]} for country in impacts_yearsets_crops_ordered}

# %%
impacts
# Out:
# {'USA': {'RF': <climada.engine.impact.Impact at 0x7fec785fc7c0>},
#  'TWN': {'RF': <climada.engine.impact.Impact at 0x7fec68d109d0>},
#  'HTI': {'RF': <climada.engine.impact.Impact at 0x7fec68d10910>},
#  'MDG': {'RF': <climada.engine.impact.Impact at 0x7fec68d10a60>},
#  'COL': {'RF': <climada.engine.impact.Impact at 0x7fec785fca30>},
#  'AUS': {'RF': <climada.engine.impact.Impact at 0x7fec8df5bdf0>},
#  'VNM': {'RF': <climada.engine.impact.Impact at 0x7fec8df5bb20>}}

# %%
impacts_yearsets_ordered =

# %%
impacts_yearsets_ordered[country]['RF'][0].imp_mat
# Out:
# <400x16092 sparse matrix of type '<class 'numpy.float64'>'
# 	with 443606 stored elements in Compressed Sparse Row format>

# %%
impacts_yearsets_crops[country]['CP'][0].imp_mat
# Out:
# <400x114 sparse matrix of type '<class 'numpy.float64'>'
# 	with 45440 stored elements in Compressed Sparse Row format>

# %%
impacts_yearsets_crops_ordered[country]['CP'][0].event_name
# Out:
# ['2030_lpjml_miroc5',
#  '2030_gepic_miroc5',
#  '2030_gepic_miroc5',
#  '2030_lpjml_miroc5',
#  '2030_lpjml_miroc5',
#  '2030_lpjml_ipsl-cm5a-lr',
#  '2030_pepic_ipsl-cm5a-lr',
#  '2030_gepic_ipsl-cm5a-lr',
#  '2030_gepic_ipsl-cm5a-lr',
#  '2030_pepic_ipsl-cm5a-lr',
#  '2030_pepic_gfdl-esm2m',
#  '2030_pepic_gfdl-esm2m',
#  '2030_gepic_gfdl-esm2m',
#  '2030_lpjml_gfdl-esm2m',
#  '2030_pepic_gfdl-esm2m',
#  '2030_pepic_hadgem2-es',
#  '2030_gepic_hadgem2-es',
#  '2030_lpjml_hadgem2-es',
#  '2030_gepic_hadgem2-es',
#  '2030_lpjml_hadgem2-es',
#  '2031_gepic_miroc5',
#  '2031_pepic_miroc5',
#  '2031_gepic_miroc5',
#  '2031_pepic_miroc5',
#  '2031_pepic_miroc5',
#  '2031_gepic_ipsl-cm5a-lr',
#  '2031_lpjml_ipsl-cm5a-lr',
#  '2031_pepic_ipsl-cm5a-lr',
#  '2031_pepic_ipsl-cm5a-lr',
#  '2031_lpjml_ipsl-cm5a-lr',
#  '2031_gepic_gfdl-esm2m',
#  '2031_lpjml_gfdl-esm2m',
#  '2031_gepic_gfdl-esm2m',
#  '2031_pepic_gfdl-esm2m',
#  '2031_pepic_gfdl-esm2m',
#  '2031_lpjml_hadgem2-es',
# ...

# %%
impacts_yearsets_crops[country]['CP'][0].at_event
# Out:
# array([ -190181.51434472,  -661517.39028417, -2536953.72039483,
#          215009.31379564,  -623369.27135997,  1362023.70948971,
#         -329908.22783782,    67275.47540222,  4009504.49745703,
#        -1944307.27553025, -2262809.510869  ,   799395.74972071,
#         -168268.09346499,   526005.98419048,  -141885.08136966,
#         1084405.66446513,  -665355.34451515, -4492144.67322339,
#        -1949239.94870314,  -295489.30307473,   -32438.52352124,
#        -1309989.62058208,  2520663.38579444,  -518982.65850735,
#          -78368.50711022, -2479701.65994394,   826892.96847106,
#         1978308.38938403, -2743566.6572331 , -1821392.36594386,
#         3260489.72495731,  1383565.06672588,  2951234.7323355 ,
#         -346091.33623356,  1346246.06485123,  2667823.80492048,
#        -1606846.55604527,  3598979.7074079 ,  3977472.68357679,
#         2608795.71243468,   557042.69791511,  -185247.43264519,
#           12663.86204078,  1652016.75180565, -2338729.77771291,
# ...

# %%
fig,ax = plt.subplots()
impacts_yearsets_crops_ordered[country]['CP'][0].calc_freq_curve().plot(axis=ax,color='orange')
impacts_yearsets_crops[country]['CP'][0].calc_freq_curve().plot(axis=ax, color='Blue')
# Out:
# <AxesSubplot:title={'center':'Exceedance frequency curve'}, xlabel='Return period (year)', ylabel='Impact (t/y)'>

# %%
country ='VNM'

# %%
impacts_yearsets_crops[country]['CP'][0].imp_mat
# Out:
# <400x114 sparse matrix of type '<class 'numpy.float64'>'
# 	with 45440 stored elements in Compressed Sparse Row format>

# %%
np.corrcoef(impacts_yearsets_crops_ordered[country]['CP'][0].at_event,impacts_yearsets_ordered[country]['RF'][0].at_event)
# Out:
# array([[ 1.        , -0.26304521],
#        [-0.26304521,  1.        ]])

# %%
np.corrcoef(impacts_yearsets_crops[country]['CP'][0].at_event,impacts_yearsets[country]['RF'][0].at_event)
# Out:
# array([[1.        , 0.02297917],
#        [0.02297917, 1.        ]])

# %%
fig,ax = plt.subplots()


ax.scatter(impacts_yearsets_crops[country]['CP'][0].at_event,impacts_yearsets[country]['RF'][0].at_event)

fig,ax = plt.subplots()



ax.scatter(impacts_yearsets_crops_ordered[country]['CP'][0].at_event,impacts_yearsets_ordered[country]['RF'][0].at_event)

# %%
path_windfields = '/Users/szelie/OneDrive - ETH Zurich/data/windfields/Trial1_GB_dkgfdl_rcp60cal_N_0360as.mat'

# %%
from climada.hazard.trop_cyclone import TropCyclone

# %%
tc = TropCyclone.from_mat(path_windfields)

# %%
tc_list = []
models_list = []
year_start = 2030
year_end = 2050
event_name_list = []
climate_models = ['miroc','ipsl','gfdl','had']
model_full_name = {'miroc':'miroc5','ipsl':'ipsl-cm5a-lr','gfdl':'gfdl-esm2m','had':'hadgem2-es'}
for n,model in enumerate(climate_models):
    path_windfields = "".join(['/Users/szelie/OneDrive - ETH Zurich/data/windfields/Trial1_GB_dk',model,'_rcp60cal_S_0360as.mat'])
    tc_south = TropCyclone.from_mat(path_windfields)
    path_windfields = "".join(['/Users/szelie/OneDrive - ETH Zurich/data/windfields/Trial1_GB_dk',model,'_rcp60cal_N_0360as.mat'])
    tc_north = TropCyclone.from_mat(path_windfields)
    tc = Hazard.concat([tc_south,tc_north])
    tc = tc.select(date=(datetime.date.toordinal(datetime.date(year_start, 1, 1)),datetime.date.toordinal(datetime.date(year_end, 1, 1))))
    event_name = ["".join([str( datetime.date.fromordinal(np.min(date)).year), '_', model_full_name[model]]) for date in tc.date]
    tc.frequency = np.ones(len(event_name))/(year_end - year_start)/len(climate_models)
    tc_list.append(tc)
    event_name_list.append(event_name)
tc = TropCyclone.concat(tc_list) 
tc.event_name = np.concatenate(event_name_list)

# %%
tc.plot_inten
# Out:
# <24002x1656093 sparse matrix of type '<class 'numpy.float64'>'
# 	with 17525917 stored elements in Compressed Sparse Row format>

# %%
def aggregate_impact_from_event_name(imp, exp=None):
    """
    Aggregate the impact per year to make yearsets. Maximum impact per year
    at each exposure point is exposure value if exp is not None.

    Parameters
    ----------
    imp : Impact
        Impact with an impact matrix and events with dates per year

    exp : Exposure
        Exposure of Impact.
    Raises
    ------
    AttributeError
        If impact matrix is empty.

    Returns
    -------
    impact : Impact
        Impact yearset.

    """
    #if imp.imp_mat.nnz == 0:
    #    raise AttributeError("The impact matrix from imp.imp_mat is empty.")

    impact = copy.deepcopy(imp)
    imp_mat = sum_impact_by_event_name(impact, exp)
    impact.frequency = np.ones(imp_mat.shape[0])/imp_mat.shape[0]
    impact = impact.set_imp_mat(imp_mat)
    impact.date = np.arange(1, len(impact.at_event) + 1)
    impact.event_id = np.arange(1, len(impact.at_event) + 1)
    impact.event_name = np.unique(imp.event_name)
    impact.tag['yimp object'] = True
    return impact

def sum_impact_by_event_name(imp, exp=None):
    """
    Sum the impact for all events in the same year. Impact per year cannot
    exceed exposures value.

    Parameters
    ----------
    imp : Impact
        Impact with impact matrix and events over several years
    exp: Exposure, optional
        Exposure of the Impact. If none, impact is simply summed.
    Returns
    -------
    sp.sparse.csr_matrix
        Impact matrix with one event per year

    """
    mat = imp.imp_mat
    mask =[np.ma.make_mask(np.array(imp.event_name) == event).astype(int)
           for event in np.unique(imp.event_name)]
    mask_matrix =  sp.sparse.csr_matrix(mask)
    sum_mat = mask_matrix.dot(mat)
    if exp is not None:
        exp_mat = np.stack([exp.gdf.value.to_numpy() for n in np.unique(imp.event_name)])
        def sparse_min(A, B):
             """
             Return the element-wise maximum of sparse matrices `A` and `B`.
             """
             AgtB = (A < B).astype(int)
             M = np.multiply(AgtB, A - B) + B
             return sp.sparse.csr_matrix(M)
        sum_mat = sparse_min(sum_mat, exp_mat)
    return sum_mat

# %%
tc.centroids.set_region_id()
# Out:
# /Users/szelie/python_projects/climada_python/climada/util/coordinates.py:1372: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   countries['area'] = countries.geometry.area

# %%
from climada.util.api_client import Client
client = Client()
exp_dict = {}
countries = ['USA','TWN', 'HTI', 'MDG','COL', 'AUS', 'VNM']
for country in countries:
    exp_dict[country] = client.get_litpop_default(country)
    #exp_dict[country].assign_centroids(tc)

# %%
from climada.entity.impact_funcs.trop_cyclone import ImpfSetTropCyclone
impf_TC = ImpfSetTropCyclone.from_calibrated_regional_ImpfSet()
def get_id(cnt):
    for basin, iso_list in impf_TC.get_countries_per_region()[3].items():
        for iso in iso_list:
            if iso == cnt:
                return basin, impf_TC.get_countries_per_region()[1][basin]
for cnt, exp in exp_dict.items():
    impf_id = get_id(cnt)[1]
    exp.gdf['impf_TC'] = impf_id

# %%
import pycountry
country='TWN'
years = np.arange(2030,2050)
impacts_yearsets_kerry = {}
impacts_yearsets_knutsen = {}
for country in countries:
    tc_country = tc.select(reg_id=int(pycountry.countries.get(alpha_3=country).numeric))
    impacts_yearsets_kerry[country] = {}
    impacts_yearsets_knutsen[country] = {}
    tc_knutsen = client.get_hazard('tropical_cyclone', properties={'country_iso3alpha': country, 'climate_scenario':'rcp26',  'nb_synth_tracks':'10', 'ref_year':'2040'})
    imp_kerry = Impact()
    exp_dict[country].assign_centroids(tc_country)
    imp_knutsen = Impact()
    imp_kerry.calc(exp_dict[country], impf_TC, tc_country, save_mat=True)
    exp_dict[country].assign_centroids(tc_knutsen)
    imp_knutsen.calc(exp_dict[country], impf_TC, tc_knutsen, save_mat=True)
    imp_per_year_kerry = aggregate_impact_from_event_name(imp_kerry, exp_dict[country])
    years_yearsets = np.array(range(1,401))
    impacts_yearsets_kerry[country]['TC'] = make_yearset(imp_per_year_kerry, years_yearsets, exposures=exp_dict[country], n_samples=1)
    impacts_yearsets_knutsen[country]['TC'] = make_yearset(imp_knutsen, years_yearsets, exposures=exp_dict[country], n_samples=1)


climate_models = ['miroc5','ipsl-cm5a-lr','gfdl-esm2m','hadgem2-es']
#impacts_yearsets_ordered = {country: {hazard: [order_climate_driver(impacts_yearsets[country][hazard][0], climate_models, years)] for hazard in impacts_yearsets[country]} for country in countries}
impacts_yearsets_ordered_kerry = {country: {'TC': [order_climate_driver(impacts_yearsets_kerry[country]['TC'][0], climate_models, years)]} for country in countries}
# Out:
# 2022-05-03 15:35:16,492 - climada.util.coordinates - WARNING - Distance to closest centroid is greater than 100km for 79 coordinates.
# 2022-05-03 15:35:16,513 - climada.util.coordinates - WARNING - Distance to closest centroid is greater than 100km for 1 coordinates.
# 2022-05-03 15:35:18,097 - climada.util.coordinates - WARNING - Distance to closest centroid is greater than 100km for 129752 coordinates.
# /Users/szelie/miniconda3/envs/climada_env/lib/python3.8/site-packages/numpy/core/fromnumeric.py:3208: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   return asarray(a).size
# ...

# %%
impacts_yearsets_crops_ordered[country]['CP'][0].event_name
# Out:
# ['2030_lpjml_miroc5',
#  '2030_gepic_miroc5',
#  '2030_gepic_miroc5',
#  '2030_lpjml_miroc5',
#  '2030_lpjml_miroc5',
#  '2030_lpjml_ipsl-cm5a-lr',
#  '2030_pepic_ipsl-cm5a-lr',
#  '2030_gepic_ipsl-cm5a-lr',
#  '2030_gepic_ipsl-cm5a-lr',
#  '2030_pepic_ipsl-cm5a-lr',
#  '2030_pepic_gfdl-esm2m',
#  '2030_pepic_gfdl-esm2m',
#  '2030_gepic_gfdl-esm2m',
#  '2030_lpjml_gfdl-esm2m',
#  '2030_pepic_gfdl-esm2m',
#  '2030_pepic_hadgem2-es',
#  '2030_gepic_hadgem2-es',
#  '2030_lpjml_hadgem2-es',
#  '2030_gepic_hadgem2-es',
#  '2030_lpjml_hadgem2-es',
#  '2031_gepic_miroc5',
#  '2031_pepic_miroc5',
#  '2031_gepic_miroc5',
#  '2031_pepic_miroc5',
#  '2031_pepic_miroc5',
#  '2031_gepic_ipsl-cm5a-lr',
#  '2031_lpjml_ipsl-cm5a-lr',
#  '2031_pepic_ipsl-cm5a-lr',
#  '2031_pepic_ipsl-cm5a-lr',
#  '2031_lpjml_ipsl-cm5a-lr',
#  '2031_gepic_gfdl-esm2m',
#  '2031_lpjml_gfdl-esm2m',
#  '2031_gepic_gfdl-esm2m',
#  '2031_pepic_gfdl-esm2m',
#  '2031_pepic_gfdl-esm2m',
#  '2031_lpjml_hadgem2-es',
# ...

# %%
impacts_yearsets_ordered_kerry['USA']['TC'][0].event_name
# Out:
# ['2030_miroc5',
#  '2030_miroc5',
#  '2030_miroc5',
#  '2030_miroc5',
#  '2030_miroc5',
#  '2030_ipsl-cm5a-lr',
#  '2030_ipsl-cm5a-lr',
#  '2030_ipsl-cm5a-lr',
#  '2030_ipsl-cm5a-lr',
#  '2030_ipsl-cm5a-lr',
#  '2030_gfdl-esm2m',
#  '2030_gfdl-esm2m',
#  '2030_gfdl-esm2m',
#  '2030_gfdl-esm2m',
#  '2030_gfdl-esm2m',
#  '2030_hadgem2-es',
#  '2030_hadgem2-es',
#  '2030_hadgem2-es',
#  '2030_hadgem2-es',
#  '2030_hadgem2-es',
#  '2031_miroc5',
#  '2031_miroc5',
#  '2031_miroc5',
#  '2031_miroc5',
#  '2031_miroc5',
#  '2031_ipsl-cm5a-lr',
#  '2031_ipsl-cm5a-lr',
#  '2031_ipsl-cm5a-lr',
#  '2031_ipsl-cm5a-lr',
#  '2031_ipsl-cm5a-lr',
#  '2031_gfdl-esm2m',
#  '2031_gfdl-esm2m',
#  '2031_gfdl-esm2m',
#  '2031_gfdl-esm2m',
#  '2031_gfdl-esm2m',
#  '2031_hadgem2-es',
#  '2031_hadgem2-es',
#  '2031_hadgem2-es',
#  '2031_hadgem2-es',
#  '2031_hadgem2-es',
#  '2032_miroc5',
#  '2032_miroc5',
#  '2032_miroc5',
#  '2032_miroc5',
#  '2032_miroc5',
#  '2032_ipsl-cm5a-lr',
#  '2032_ipsl-cm5a-lr',
# ...

# %%
for country in countries:

    fig,ax = plt.subplots()

    #impacts_yearsets_kerry[country]['TC'][0].calc_freq_curve().plot(axis=ax,color='orange')
    impacts_yearsets_knutsen[country]['TC'][0].calc_freq_curve().plot(axis=ax,color='red', label='knutsen')
    impacts_yearsets_ordered_kerry[country]['TC'][0].calc_freq_curve().plot(axis=ax,color='blue', label='kerry')
    ax.set_title(country +' RCP6.0 2040')
    ax.legend()
    ax.set_xlim(0,100)

# %%
impacts_yearsets_ordered_kerry[country]['TC'][0].event_name
# Out:
# ['2030_miroc5',
#  '2030_miroc5',
#  '2030_miroc5',
#  '2030_miroc5',
#  '2030_miroc5',
#  '2030_ipsl-cm5a-lr',
#  '2030_ipsl-cm5a-lr',
#  '2030_ipsl-cm5a-lr',
#  '2030_ipsl-cm5a-lr',
#  '2030_ipsl-cm5a-lr',
#  '2030_gfdl-esm2m',
#  '2030_gfdl-esm2m',
#  '2030_gfdl-esm2m',
#  '2030_gfdl-esm2m',
#  '2030_gfdl-esm2m',
#  '2030_hadgem2-es',
#  '2030_hadgem2-es',
#  '2030_hadgem2-es',
#  '2030_hadgem2-es',
#  '2030_hadgem2-es',
#  '2031_miroc5',
#  '2031_miroc5',
#  '2031_miroc5',
#  '2031_miroc5',
#  '2031_miroc5',
#  '2031_ipsl-cm5a-lr',
#  '2031_ipsl-cm5a-lr',
#  '2031_ipsl-cm5a-lr',
#  '2031_ipsl-cm5a-lr',
#  '2031_ipsl-cm5a-lr',
#  '2031_gfdl-esm2m',
#  '2031_gfdl-esm2m',
#  '2031_gfdl-esm2m',
#  '2031_gfdl-esm2m',
#  '2031_gfdl-esm2m',
#  '2031_hadgem2-es',
#  '2031_hadgem2-es',
#  '2031_hadgem2-es',
#  '2031_hadgem2-es',
#  '2031_hadgem2-es',
#  '2032_miroc5',
#  '2032_miroc5',
#  '2032_miroc5',
#  '2032_miroc5',
#  '2032_miroc5',
#  '2032_ipsl-cm5a-lr',
#  '2032_ipsl-cm5a-lr',
# ...

# %%
combined_impact_ordered = combine_yearly_impacts([impacts_yearsets_ordered_kerry[country]['TC'][0], impacts_yearsets_ordered[country]['RF'][0]])
combined_impact = combine_yearly_impacts([impacts_yearsets_kerry[country]['TC'][0], impacts_yearsets[country]['RF'][0]])

for country in ['USA']:
    combined_impact_ordered = combine_yearly_impacts([impacts_yearsets_ordered_kerry[country]['TC'][0], impacts_yearsets_ordered[country]['RF'][0]])
    combined_impact = combine_yearly_impacts([impacts_yearsets_kerry[country]['TC'][0], impacts_yearsets[country]['RF'][0]])


    fig,ax = plt.subplots()

    #impacts_yearsets_kerry[country]['TC'][0].calc_freq_curve().plot(axis=ax,color='orange')
    combined_impact_ordered.calc_freq_curve().plot(axis=ax,color='red', label='ordered')
    combined_impact.calc_freq_curve().plot(axis=ax,color='blue', label='random')
    ax.set_title(country +' combined RF and TC RCP6.0 2040')
    ax.legend()
    ax.set_xlim(0,100)

# %%
fig,ax = plt.subplots()


ax.scatter(np.log(impacts_yearsets_ordered_kerry[country]['TC'][0].at_event), np.log(impacts_yearsets_ordered[country]['RF'][0].at_event))
# Out:
# /var/folders/f5/lms0b90j1kx7kk4v552qkjqw0000gp/T/ipykernel_21320/1383106412.py:4: RuntimeWarning: divide by zero encountered in log
#   ax.scatter(np.log(impacts_yearsets_ordered_kerry[country]['TC'][0].at_event), np.log(impacts_yearsets_ordered[country]['RF'][0].at_event))

# %%
impacts_yearsets_ordered_kerry[country]['TC'][0].imp_mat.todense().flatten()
# Out:
# matrix([[0., 0., 0., ..., 0., 0., 0.]])

# %%
impacts_yearsets_crops_ordered[country]['CP'][0].at_event
# Out:
# array([ 1640008.95768499, -3632805.85513313, -3632805.85513313,
#         1640008.95768499,  1640008.95768499, -2398416.69009163,
#        -1501731.3517242 , -4475879.83630549, -4475879.83630549,
#        -1501731.3517242 ,  1433989.27144239,  1433989.27144239,
#        -3515553.4846686 , -1827248.40688202,  1433989.27144239,
#        -2479701.65994394,   541896.15916492,  3873366.95997512,
#          541896.15916492,  3873366.95997512,  -665355.34451515,
#         -480458.14527162,  -665355.34451515,  -480458.14527162,
#         -480458.14527162, -1536610.57642035,  3260489.72495731,
#          194026.00240187,   194026.00240187,  3260489.72495731,
#         -692722.73824689,  2186634.30272056,  -692722.73824689,
#         2951234.7323355 ,  2951234.7323355 ,  4638520.90314903,
#         3679028.41278976,  3679028.41278976,  3679028.41278976,
#         4638520.90314903,   600107.10127687,   600107.10127687,
#          600107.10127687,  1571544.81872161,  1571544.81872161,
# ...

# %%
country = 'VNM'

np.corrcoef(np.log(impacts_yearsets_ordered_kerry[country]['TC'][0].at_event), np.log(impacts_yearsets_crops_ordered[country]['CP'][0].at_event))
# Out:
# /var/folders/f5/lms0b90j1kx7kk4v552qkjqw0000gp/T/ipykernel_21320/3345983984.py:3: RuntimeWarning: invalid value encountered in log
#   np.corrcoef(np.log(impacts_yearsets_ordered_kerry[country]['TC'][0].at_event), np.log(impacts_yearsets_crops_ordered[country]['CP'][0].at_event))
# array([[ 1., nan],
#        [nan, nan]])

# %%
fig,ax = plt.subplots()


ax.scatter(np.log(impacts_yearsets_ordered_kerry[country]['TC'][0].at_event), np.log(impacts_yearsets_crops_ordered[country]['CP'][0].at_event))
# Out:
# /var/folders/f5/lms0b90j1kx7kk4v552qkjqw0000gp/T/ipykernel_21320/2171645063.py:4: RuntimeWarning: invalid value encountered in log
#   ax.scatter(np.log(impacts_yearsets_ordered_kerry[country]['TC'][0].at_event), np.log(impacts_yearsets_crops_ordered[country]['CP'][0].at_event))

# %%
np.corrcoef(impacts_yearsets_kerry[country]['TC'][0].at_event,impacts_yearsets_crops[country]['CP'][0].at_event)
# Out:
# array([[ 1.        , -0.03183436],
#        [-0.03183436,  1.        ]])

# %%
impacts_yearsets_kerry[country]['TC'][0].aai_agg
# Out:
# 5070668546.638719

# %%
fig,ax = plt.subplots()
ax.scatter(impacts_yearsets_ordered['ITA']['TC'][0].at_event,impacts_yearsets_ordered['HTI']['RF'][0].at_event)

fig,ax = plt.subplots()
ax.scatter(impacts_yearsets_crops_ordered['ITA']['CP'][0].at_event,impacts_yearsets_ordered['ITA']['RF'][0].at_event)

# %%
rf_events_high = impacts_yearsets_ordered['ITA']['RF'][0].at_event[impacts_yearsets_ordered['ITA']['RF'][0].at_event>10e9]

crops_events_high = impacts_yearsets_crops_ordered['ITA']['CP'][0].at_event[impacts_yearsets_ordered['ITA']['RF'][0].at_event>10e9]

# %%
fig,ax = plt.subplots()
ax.scatter(crops_events_high,rf_events_high)

# %%
fig,ax = plt.subplots()
ax.scatter(impacts_yearsets_ordered['HTI']['RF'][0].eai_exp,impacts_yearsets_ordered['HTI']['TC'][0].eai_exp)

# %%
np.corrcoef(impacts_yearsets_crops_ordered['ITA']['CP'][0].at_event,impacts_yearsets_ordered['ITA']['RF'][0].at_event)
# Out:
# array([[ 1.        , -0.07703301],
#        [-0.07703301,  1.        ]])

# %%
np.corrcoef(impacts_yearsets_ordered['AUS']['TC'][0].imp_mat.todense().flatten(),impacts_yearsets_ordered['AUS']['RF'][0].imp_mat.todense().flatten())
# Out:
# array([[ 1.        , -0.00627234],
#        [-0.00627234,  1.        ]])
